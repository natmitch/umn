# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:password@localhost/class_activities_db")

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM wordassociation")
for record in data:
    print(record)
# Out:
# (1, 289, 'maudie', 'atticus', 'AC')
# (2, 312, 'limpet', 'mine', 'AC')
# (3, 235, 'magneto', 'fiction', 'AC')
# (4, 312, 'john deere', 'tractor', 'AC')
# (5, 218, 'read', 'library', 'AC')
# (6, 262, 'composition', 'computer', 'AC')
# (7, 248, 'toilet', 'break', 'AC')
# (8, 235, 'elusive', 'butterfly', 'AC')
# (9, 39, 'fire', 'habanero', 'AC')
# (10, 42, 'boat', 'sink', 'AC')
# (11, 133, 'break', 'leg', 'AC')
# (12, 22, 'travel', 'explore', 'AC')
# (13, 12, 'round', 'top', 'AC')
# (14, 12, 'deceit', 'catfish', 'AC')
# (15, 309, 'choreography', 'drama', 'AC')
# (16, 248, 'back flip', 'cartwheel', 'AC')
# (17, 235, 'phobia', 'mania', 'AC')
# (18, 312, 'tiramisu', 'italy', 'AC')
# (19, 12, 'head', 'gasket', 'AC')
# (20, 115, 'brimstone', 'sulfur', 'AC')
# (21, 97, 'stone', 'henge', 'AC')
# (22, 312, 'temple', 'ephesus', 'AC')
# (23, 42, 'flash flood', 'beads', 'AC')
# (24, 12, 'sheep', 'wool', 'AC')
# (25, 39, 'ganja', 'garden', 'AC')
# (26, 172, 'pima', 'sioux', 'AC')
# ...

# %%
# Query Single Record in the the Database
data = engine.execute("SELECT * FROM icecreamstore WHERE Price>=1.25;")
for record in data:
    print(record)
# Out:
# (2, 'Chocolate', 150, Decimal('1.25'))
# (3, 'Strawberry', 95, Decimal('1.25'))
# (4, 'Rocky Road', 50, Decimal('1.50'))
# (5, 'Cookie Dough', 75, Decimal('1.50'))
